# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Buy_Data.xlsx')
df
# Out:
#      Unnamed: 0  BHK  Baths  Total_Area_SqFt  Price_per_SqFt  \
# 0             0    3      3             2250            4488
# 1             1    3      3             1350           12592
# 2             2    2      2             1193            9807
# 3             3    4      4             2700           11111
# 4             4    4      4             4842           12391
# ..          ...  ...    ...              ...             ...
# 186         186    3      3             2000           12000
# 187         187    4      4             2700           12222
# 188         188    2      2             1145            5414
# 189         189    2      0             6138           33398
# 190         190    2      0             2259           32094
#
#                 Type_of_Land                     Area     Price     Location
# 0              Bedroom House               Pari Chowk  10100000  Delhi / NCR
# 1                  Apartment     Sector B Vasant Kunj  17000000  Delhi / NCR
# 2                  Apartment        Sector 79 Gurgaon  11700000  Delhi / NCR
# 3                        NaN              DLF Phase 1  30000000  Delhi / NCR
# 4                        NaN              DLF Phase 1  60000000  Delhi / NCR
# ..                       ...                      ...       ...          ...
# 186                      NaN              DLF Phase 1  24000000  Delhi / NCR
# 187                      NaN      Sushant Lok Phase 1  33000000  Delhi / NCR
# 188                Apartment  Sector 16 Greater Noida   6200000  Delhi / NCR
# 189  Residential land / Plot              DLF Phase 2   2050000  Delhi / NCR
# 190  Residential land / Plot              DLF Phase 2  72500000  Delhi / NCR
#
# [191 rows x 9 columns]

# %%
df = df.drop("Unnamed: 0",axis=1)
df
# Out:
#      BHK  Baths  Total_Area_SqFt  Price_per_SqFt             Type_of_Land  \
# 0      3      3             2250            4488            Bedroom House
# 1      3      3             1350           12592                Apartment
# 2      2      2             1193            9807                Apartment
# 3      4      4             2700           11111                      NaN
# 4      4      4             4842           12391                      NaN
# ..   ...    ...              ...             ...                      ...
# 186    3      3             2000           12000                      NaN
# 187    4      4             2700           12222                      NaN
# 188    2      2             1145            5414                Apartment
# 189    2      0             6138           33398  Residential land / Plot
# 190    2      0             2259           32094  Residential land / Plot
#
#                         Area     Price     Location
# 0                 Pari Chowk  10100000  Delhi / NCR
# 1       Sector B Vasant Kunj  17000000  Delhi / NCR
# 2          Sector 79 Gurgaon  11700000  Delhi / NCR
# 3                DLF Phase 1  30000000  Delhi / NCR
# 4                DLF Phase 1  60000000  Delhi / NCR
# ..                       ...       ...          ...
# 186              DLF Phase 1  24000000  Delhi / NCR
# 187      Sushant Lok Phase 1  33000000  Delhi / NCR
# 188  Sector 16 Greater Noida   6200000  Delhi / NCR
# 189              DLF Phase 2   2050000  Delhi / NCR
# 190              DLF Phase 2  72500000  Delhi / NCR
#
# [191 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['BHK', 'Baths', 'Total_Area_SqFt', 'Price_per_SqFt', 'Type_of_Land',
#        'Area', 'Price', 'Location'],
#       dtype='object')

# %%
df.shape
# Out:
# (191, 8)

# %%
#'duplicated()' function in pandas return the duplicate row as True and othter as False
#for counting the duplicate elements we sum all the rows
sum(df.duplicated())
# Out:
# 7

# %%
df = df.drop_duplicates(keep='last')
df
# Out:
#      BHK  Baths  Total_Area_SqFt  Price_per_SqFt             Type_of_Land  \
# 0      3      3             2250            4488            Bedroom House
# 1      3      3             1350           12592                Apartment
# 2      2      2             1193            9807                Apartment
# 4      4      4             4842           12391                      NaN
# 5      4      4             4518            9960                      NaN
# ..   ...    ...              ...             ...                      ...
# 186    3      3             2000           12000                      NaN
# 187    4      4             2700           12222                      NaN
# 188    2      2             1145            5414                Apartment
# 189    2      0             6138           33398  Residential land / Plot
# 190    2      0             2259           32094  Residential land / Plot
#
#                         Area     Price     Location
# 0                 Pari Chowk  10100000  Delhi / NCR
# 1       Sector B Vasant Kunj  17000000  Delhi / NCR
# 2          Sector 79 Gurgaon  11700000  Delhi / NCR
# 4                DLF Phase 1  60000000  Delhi / NCR
# 5                DLF Phase 1  45000000  Delhi / NCR
# ..                       ...       ...          ...
# 186              DLF Phase 1  24000000  Delhi / NCR
# 187      Sushant Lok Phase 1  33000000  Delhi / NCR
# 188  Sector 16 Greater Noida   6200000  Delhi / NCR
# 189              DLF Phase 2   2050000  Delhi / NCR
# 190              DLF Phase 2  72500000  Delhi / NCR
#
# [184 rows x 8 columns]

# %%
df.to_csv('Delhi .csv')

# %%
df.shape
# Out:
# (184, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184 entries, 0 to 190
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BHK              184 non-null    int64
#  1   Baths            184 non-null    int64
#  2   Total_Area_SqFt  184 non-null    int64
#  3   Price_per_SqFt   184 non-null    int64
#  4   Type_of_Land     76 non-null     object
#  5   Area             184 non-null    object
#  6   Price            184 non-null    int64
#  7   Location         184 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 12.9+ KB

# %%
plt.figure(figsize = (4,4))
ax = df.dtypes.value_counts().plot(kind='bar',grid = False,fontsize=20,color='grey')
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+ p.get_width() / 2., height + 1, height, ha = 'center', size = 25)
sns.despine()

# %%
df.describe().T
# Out:
#                  count          mean           std        min          25%  \
# BHK              184.0  5.326087e+00  9.752241e+00        1.0         3.00
# Baths            184.0  3.021739e+00  1.786276e+00        0.0         2.00
# Total_Area_SqFt  184.0  2.890750e+03  1.652204e+03      300.0      1850.00
# Price_per_SqFt   184.0  1.506689e+04  1.114183e+04     3128.0      9792.75
# Price            184.0  2.665596e+07  1.855372e+07  1000000.0  12875000.00
#
#                         50%         75%         max
# BHK                     4.0         4.0        81.0
# Baths                   3.0         4.0        12.0
# Total_Area_SqFt      2700.0      3618.0      9600.0
# Price_per_SqFt      11148.0     16202.5     81481.0
# Price            24000000.0  38625000.0  89000000.0

# %%
#since the dataset contain null values also 
#count total rows in each column which contain null values
df.isna().sum()
# Out:
# BHK                  0
# Baths                0
# Total_Area_SqFt      0
# Price_per_SqFt       0
# Type_of_Land       108
# Area                 0
# Price                0
# Location             0
# dtype: int64

# %%
df['Type_of_Land'].value_counts()
# Out:
# Apartment                        32
# Residential land / Plot          30
# Bedroom House                    12
# Bedroom Farm house                1
# Studio Apartments /  RK Flats     1
# Name: Type_of_Land, dtype: int64

# %%
ax = sns.countplot(x='Type_of_Land', data=df)
ax.figure.set_size_inches(18.5, 5)

# %%
df.Type_of_Land.value_counts().plot(kind="pie",autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='Type_of_Land'>

# %%
# How expensive are houses?
print('The cheapest house sold for ₹{:,.0f} and the most expensive for ₹{:,.0f}'.format(
    df['Price'].min(), df['Price'].max()))
print('The average sales price is ₹{:,.0f}, while median is ₹{:,.0f}'.format(
    df['Price'].min(), df['Price'].max()))
# Out:
# The cheapest house sold for ₹1,000,000 and the most expensive for ₹89,000,000
# The average sales price is ₹1,000,000, while median is ₹89,000,000

# %%
# How big are houses
print('The average house has {:,.0f} sq ft of space, the median {:,.0f} sq ft'.format(
    df['Total_Area_SqFt'].mean(), df['Total_Area_SqFt'].median()))
print('The biggest house has {:,.0f} sq ft of space, the smallest {:,.0f} sq ft'.format(
    df['Total_Area_SqFt'].max(), df['Total_Area_SqFt'].min()))
# Out:
# The average house has 2,891 sq ft of space, the median 2,700 sq ft
# The biggest house has 9,600 sq ft of space, the smallest 300 sq ft

# %%
fig, ax = plt.subplots(3, 2, figsize = (15,10))

sns.boxplot(df.BHK, ax = ax[0, 0])
sns.boxplot(df.Baths, ax = ax[0, 1])
sns.boxplot(df.Total_Area_SqFt, ax = ax[1, 0])
sns.boxplot(df.Price_per_SqFt, ax = ax[2, 0])
sns.boxplot(df.Price, ax = ax[2, 1])

plt.tight_layout()
plt.show()

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    return np.where((ys > upper_bound) | (ys < lower_bound))

list_atributes = ['BHK', 'Baths', 'Total_Area_SqFt', 'Price_per_SqFt', 'Price']
print("Outliers: \n")
for item in list_atributes:
    print(item,': ',outliers_iqr(df[item]))
# Out:
# Outliers:
#
# BHK :  (array([ 48,  63,  64,  69,  70,  71,  77,  78,  79,  89,  90,  94,  95,
#         97, 101, 102, 108, 113, 126, 127, 128, 134, 141, 142, 148, 156,
#        163, 165, 170], dtype=int64),)
# Baths :  (array([ 69, 101, 134], dtype=int64),)
# Total_Area_SqFt :  (array([ 70,  71, 119, 128, 143, 149], dtype=int64),)
# Price_per_SqFt :  (array([ 48,  69,  70,  73,  74,  75,  77,  94,  95,  97, 100, 101, 102,
#        111, 113, 126, 127, 128, 132, 134, 141, 142, 143, 144, 145, 146,
#        152, 153, 177, 182, 183], dtype=int64),)
# Price :  (array([ 75, 146], dtype=int64),)

# %%
fig, ax = plt.subplots(3, 2, figsize = (15,10))

sns.distplot(df.BHK, ax = ax[0, 0])
sns.distplot(df.Baths, ax = ax[0, 1])
sns.distplot(df.Total_Area_SqFt, ax = ax[1, 0])
sns.distplot(df.Price_per_SqFt, ax = ax[2, 0])
sns.distplot(df.Price, ax = ax[2, 1])

plt.tight_layout()
plt.show()

# %%
col = df.select_dtypes(exclude = 'object').columns.tolist()

data = df[col]
pd.DataFrame(data = [data.skew(), data.kurtosis()],index = ['skewness', 'kurtosis'])
# Out:
#                 BHK     Baths  Total_Area_SqFt  Price_per_SqFt     Price
# skewness   6.048852  0.502007         1.555870        2.389478  0.659598
# kurtosis  39.829779  3.570837         3.885205        7.940909  0.095340

# %%
#Format the plot background and scatter plots for all the variables
columns = ['BHK', 'Baths', 'Total_Area_SqFt', 'Price_per_SqFt','Price']
sns.pairplot(df[columns])

# %%
def plot_correlation(df, columns):
    corr = df[columns].corr()
    sns.heatmap(corr, annot=True)

# %%
columns = ['BHK', 'Baths', 'Total_Area_SqFt', 'Price_per_SqFt','Price']
plot_correlation(df, columns)

# %%
# Feature sorted by correlation from positive to negative

# %%
corr = df.corr()
corr = corr.sort_values('BHK', ascending=False)
plt.figure(figsize=(5,5))
sns.barplot( corr.BHK[1:], corr.index[1:], orient='h')
plt.show()

# %%
corr = df.corr()
corr = corr.sort_values('Baths', ascending=False)
plt.figure(figsize=(5,5))
sns.barplot( corr.Baths[1:], corr.index[1:], orient='h')
plt.show()

# %%
corr = df.corr()
corr = corr.sort_values('Total_Area_SqFt', ascending=False)
plt.figure(figsize=(5,5))
sns.barplot( corr.Total_Area_SqFt[1:], corr.index[1:], orient='h')
plt.show()

# %%
corr = df.corr()
corr = corr.sort_values('Price_per_SqFt', ascending=False)
plt.figure(figsize=(5,5))
sns.barplot( corr.Price_per_SqFt[1:], corr.index[1:], orient='h')
plt.show()

# %%
corr = df.corr()
corr = corr.sort_values('Price', ascending=False)
plt.figure(figsize=(5,5))
sns.barplot( corr.Price[1:], corr.index[1:], orient='h')
plt.show()

# %%
plt.figure(figsize=(12, 10), dpi=80)
plt.scatter(df['Price'], df['Type_of_Land'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13216\2054291610.py in <module>
#       1 plt.figure(figsize=(12, 10), dpi=80)
# ----> 2 plt.scatter(df['Price'], df['Type_of_Land'])
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2817         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2818         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2819     __ret = gca().scatter(
#    2820         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2821         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4354         """
#    4355         # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4356         x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4357         # np.ma.ravel yields an ndarray, not a masked array,
#    4358         # unless its argument is a masked array.
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, datasets, kwargs, convert)
#    2524             # Update from data if axis is already set but no unit is set yet.
#    2525             if axis is not None and data is not None and not axis.have_units():
# -> 2526                 axis.update_units(data)
#    2527         for axis_name, axis in axis_map.items():
#    2528             # Return if no axis is set.
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1447         neednew = self.converter != converter
#    1448         self.converter = converter
# -> 1449         default = self.converter.default_units(data, self)
#    1450         if default is not None and self.units is None:
#    1451             self.set_units(default)
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     114         # the conversion call stack is default_units -> axis_info -> convert
#     115         if axis.units is None:
# --> 116             axis.set_units(UnitData(data))
#     117         else:
#     118             axis.units.update(data)
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     190         self._counter = itertools.count()
#     191         if data is not None:
# --> 192             self.update(data)
#     193
#     194     @staticmethod
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     225         for val in OrderedDict.fromkeys(data):
#     226             # OrderedDict just iterates over unique values in data.
# --> 227             _api.check_isinstance((str, bytes), value=val)
#     228             if convertible:
#     229                 # this will only be called so long as convertible is True.
#
# D:\imjma\anaconda3\lib\site-packages\matplotlib\_api\__init__.py in check_isinstance(_types, **kwargs)
#      91                 names.remove("None")
#      92                 names.append("None")
# ---> 93             raise TypeError(
#      94                 "{!r} must be an instance of {}, not a {}".format(
#      95                     k,
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
plt.figure(figsize=(10, 18), dpi=80)
plt.xticks(rotation=270)
plt.scatter(df['Price'], df['Location'])

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.bar(df['BHK'], df['Price'])

# %%
plt.figure(figsize=(10, 10), dpi=80)
sns.scatterplot(x=df['BHK'], y=df['Price'], data=df,hue='Type_of_Land')

# %%
plt.figure(figsize=(15, 18), dpi=80)
plt.xticks(rotation=270)
sns.scatterplot(x=df['Price'], y=df['Location'], data=df,hue='Type_of_Land')

# %%
plt.figure(figsize=(15, 12), dpi=80)
plt.xticks(rotation=270)
sns.scatterplot(x=df['Price'], y=df['Price_per_SqFt'], data=df,hue='Type_of_Land')

# %%
plt.figure(figsize=(10, 18), dpi=80)
plt.xticks(rotation=270)
sns.barplot(x=df['Price'], y=df['Location'], data=df,hue='Type_of_Land')
 
plt.show()

# %%
plt.figure(figsize=(14, 10), dpi=80)
plt.xticks(rotation=270)
#sns.barplot(x=df['Price'], y=df['Location'], data=df,hue='Type_of_Land')
 

sns.histplot(x='Price', data=df, kde=True, hue='Type_of_Land')
plt.show()

# %%
import plotly.express as px
 
# plotting the scatter chart
fig = px.scatter(df, x="BHK", y="Price",color='Type_of_Land')
 
# showing the plot
fig.show()

# %%
# plotting the scatter chart
fig = px.scatter(df, x="Total_Area_SqFt", y="Price",color='Type_of_Land')
 
# showing the plot
fig.show()
